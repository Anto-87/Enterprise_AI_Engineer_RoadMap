# %% [markdown]
# #### ExceptionHandling in Python

# %%
# Variable intialization 
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
## Caught the exception for the variable which is not assigned 
try:
    a=b
except:
    print("The variable has not been assigned")
# Out:
# The variable has not been assigned

# %%
try:
    a=b
except NameError as ex :
    print(f"The exception caught {ex}")
# Out:
# The exception caught name 'b' is not defined

# %%
## Caught the exception as divide by zero error 

try:
    c=1/0
except ZeroDivisionError as er:
    print(er)
# Out:
# division by zero

# %%
## Handling multiple exceptions
try:
    c=1/2
    a=b
except ZeroDivisionError as er:
    print(er)
except Exception as ex1:
    print(ex1)
finally:
    print("Execution completed !!")
# Out:
# name 'b' is not defined
# Execution completed !!

# %%
## Handling the file exception
try:
    5/0
    file =open('example2.txt','r')
    content = file.read()
    print(content)
except FileNotFoundError:
    print('No such file or directory')
except Exception as er:
    print(er)
# Out:
# division by zero
