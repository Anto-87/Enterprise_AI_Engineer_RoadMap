# %%
# Declaring and assiging the variables 

age=34
height=6.2
name="Anto"
is_student=False 

# print the variables

print("Age :", age)
print("Height :", height)
print("Name :", name)
print("Is Student ?.", is_student)
# Out:
# Age : 34
# Height : 6.2
# Name : Anto
# Is Student ?. False

# %%
# Naming conventions 
# variables should be descriptive 
# They must be start with a letter or an '_' and contan letter, numbers and underscores 
# variable names case sensitive 

first_name = "Antony"
last_name = "Christopher"

# invalid one 
# 2nme="rt"
# @name="ANto"

# %%
## Understanding the variable types 
## Python is dynamically typed, which means the type of the variable is determined at the run time 

age = 25
height = 6.2
name_ ="Anto"
am_student = False

# %%
# Type checking and conversion 
print(type(height))

height_str = str(height)
print(type(height_str))
print(height_str)
# Out:
# <class 'float'>
# <class 'str'>
# 6.2

# %%
str_int = int(height_str)
print(str_int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 str_int = int(height_str)
#       2 print(str_int)
#
# ValueError: invalid literal for int() with base 10: '6.2'

# %%
str_int = int(height)
print(str_int)
# Out:
# 6

# %%
# Dynamic typing 
# Alow to change the type of the variable as the program executes
var=10
print(var, type(var))

var="Hai"
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hai <class 'str'>

# %%
# Input the values from the user 

age=input("What's your age ?") 
age=int(age)
print(age, type(age))
# Out:
# 12 <class 'int'>
