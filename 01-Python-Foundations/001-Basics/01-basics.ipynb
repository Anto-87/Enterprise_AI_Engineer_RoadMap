# %%
# basic Syntax rules in Python
# Comments Illustration
'''
Comments Illustration of multiple lines
'''

# Case sensitivity 
name ="Anto"
Name = "chris"

print(Name)
print(name)
# Out:
# chris
# Anto

# %%
## Indentation 
age=36
if age>30:
    print("You are in age 30's")
else:
    print("You are not in 30's")
# Out:
# You are in age 30's

# %%
## Line Continuation 
total = 1+2+3+4+\
        5+6

print(total)
# Out:
# 21

# %%
## Multiple Statements on a single line 
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
## Semantics 
# Variable Assignment 

age =32 # age is an integer 
name ="Anto" # name is an string 

print(type(name))
print(type(age))

name=100
print(type(name))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>

# %%
# Example
if True:
    print("True get printed")
    if False:
        print("False get printed")
    print("This will be print in if section block")
print("This will be print outside block")
# Out:
# True get printed
# This will be print in if section block
# This will be print outside block
