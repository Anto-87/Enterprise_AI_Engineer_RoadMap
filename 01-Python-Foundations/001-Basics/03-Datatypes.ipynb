# %% [markdown]
# ### Datatypes in Python

# %%
## Integers 
age=35 
type(age)
# Out:
# int

# %%
# Float
height=6.7
type(height)
# Out:
# float

# %%
# String
name="Anto"
type(name)
# Out:
# str

# %%
# boolean 

is_student = True
type(is_student)
# Out:
# bool

# %%
is_student_ = bool()
print(is_student_)
# Out:
# False

# %%
# incorrect the vairable concatentation
result = name +5
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # incorrect the vairable concatentation
# ----> 2 result = name +5
#       3 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Resolve the above error 

result = name +" - "+ str(5)
print(result)
# Out:
# Anto - 5
