# %% [markdown]
# #### File Operation - Read And Write Files

# %%
with open('example.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# Hi! I am Anto. Welcome to my code
# Welcome to Python basics
# Whre we implement the concepts usign File

# %%
with open('example.txt','r') as file:
    for line in file:
        print(line.strip())
# Out:
# Hi! I am Anto. Welcome to my code
# Welcome to Python basics
# Whre we implement the concepts usign File

# %%
with open('example.txt','w') as file:
    file.write("This is the content written via Python code\n")
    file.write("This is a new line\n")

# %%
with open('example.txt','a') as file:
    file.write("This is the content written via Python code1\n")
    file.write("This is a new line")

# %%
lines=['\n First line \n','Second Line \n','Third Line\n']
with open('example.txt','a') as file:
    file.writelines(lines)

# %%
newdirectory = "package"
import os
os.makedirs(newdirectory)

# %%
items = os.listdir('.')
print(items)
# Out:
# ['example.txt', 'Fileoperations.ipynb', 'package']

# %%
dirname='folder'
file_name='text.txt'
full_path=os.path.join(os.getcwd(),dirname,file_name)

print(full_path)
# Out:
# d:\Enterprise_AI_Engineer_Roadmap\repository\Enterprise_AI_Engineer_RoadMap\01-Python-Foundations\006-FileHandling\folder\text.txt

# %%
relative_path="example.txt"
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\Enterprise_AI_Engineer_Roadmap\repository\Enterprise_AI_Engineer_RoadMap\01-Python-Foundations\006-FileHandling\example.txt
