# %% [markdown]
# #### OpenAI

# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.environ["LANGCHAIN_PROJECT"]

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}} profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000002D445BE7830> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002D443ECCFE0> root_client=<openai.OpenAI object at 0x000002D446FCF980> root_async_client
# ...

# %%
# Input and get the response from LLM
result=llm.invoke("What is generate AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a type of artificial intelligence that is capable of creating new content, such as text, images, music, and videos. It does this by learning patterns and structures from existing data and then using that understanding to generate novel outputs that mimic the originals. Generative AI models include algorithms such as generative adversarial networks (GANs), variational autoencoders (VAEs), and transformer-based models like GPT (Generative Pre-trained Transformer).\n\nThese models can be used in a wide range of applications, including content creation, design, entertainment, simulation, and enhancement of existing datasets. Generative AI is instrumental in tasks such as writing articles, composing music, creating art, designing products, and even developing complex simulations and virtual environments.\n\nThe field of generative AI is rapidly evolving, bringing both new opportunities and challenges. Among the challenges are ethical considerations, such a
# ...

# %%
### ChatPrompt Template

from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a expert AI Engineer. Provide me answers based on the question"),
        ("user", "{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a expert AI Engineer. Provide me answers based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain=prompt | llm
result=chain.invoke({"input":"What is generate AI?"})
print(result)
# Out:
# content='Generate AI, often referred to as generative AI, encompasses a set of artificial intelligence technologies and algorithms designed to create content autonomously. This includes producing text, images, music, videos, and other forms of data. Generative AI models are typically based on deep learning architectures such as Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), and Transformer-based models like GPT (Generative Pre-trained Transformer).\n\nGenerative AI can perform a variety of tasks, such as writing articles or stories, creating artwork, composing music, generating realistic human expressions in avatars, and even aiding in software development by writing code. Its applications span multiple industries, providing creative solutions, automating content production, and inspiring innovative processes.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 149, 'prompt_tokens': 30, 'total_tokens': 179, 'completio
# ...

# %%
type(result)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()

chain=prompt | llm | output_parser
result=chain.invoke({"input":"What is generate AI?"})
print(result)
# Out:
# Generative AI refers to a subset of artificial intelligence technologies focused on creating new content. It utilizes models, often based on deep learning, to generate data that mimics human-created content. This can include text, images, music, video, and even code. Generative AI models, such as Generative Adversarial Networks (GANs) and transformer-based models like GPT-3 and DALL-E, are designed to learn from existing data and produce new compositions that adhere to the patterns and structures found in the training data. These technologies have applications in various fields, including creative industries, data augmentation, and simulation.
