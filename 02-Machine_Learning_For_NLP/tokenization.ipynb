# %% [markdown]
# ### Natural language Processing

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in C:\Users\AJohnbritto\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.10.2)
# Requirement already satisfied: defusedxml in C:\Users\AJohnbritto\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (0.7.1)
# Requirement already satisfied: click in C:\Users\AJohnbritto\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in C:\Users\AJohnbritto\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\AJohnbritto\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in C:\Users\AJohnbritto\AppData\Local\Programs\Python\Python313\Lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in C:\Users\AJohnbritto\AppData\Local\Programs\Python\Python313\Lib\site-packages (from click->nltk) (0.4.6)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\AJohnbritto\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\AJohnbritto\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\AJohnbritto\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
corpus ="""
Hello welcome, to Krish Naik's NLP tutorials.
Please do watch the entire course! to become expert in NLP
"""

# %%
print(corpus)
# Out:
# Hello welcome, to Krish Naik's NLP tutorials.
# Please do watch the entire course! to become expert in NLP

# %%
 # Tokenization 
 # sentence --> Paragraphs
 from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ["\nHello welcome, to Krish Naik's NLP tutorials.",
#  'Please do watch the entire course!',
#  'to become expert in NLP']

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello welcome, to Krish Naik's NLP tutorials.
# Please do watch the entire course!
# to become expert in NLP

# %%
## paragraph -> words
## sentence -> words

from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', ',', 'to', 'Krish', 'Naik', "'s", 'NLP', 'tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP']

# %%
from nltk.tokenize import wordpunct_tokenize 
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'",
#  's',
#  'NLP',
#  'tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  "'s",
#  'NLP',
#  'tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP']
